# %%
import matplotlib.pyplot as plt
import numpy as np
y = np.array([35,30,25,20, 15,10,5])
alabels=(['a','b','c','d','e','f','g'])
myexplode = [0.1, 0, 0.1, 0,0.1,0,0.1]
plt.pie(y, labels=alabels, explode=myexplode)
plt.legend(title="alphabet:")

plt.savefig("piechart.pdf")
plt.show()
